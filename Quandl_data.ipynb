# %%
import quandl

# %%
mydata = quandl.get('EIA/PET_RWTC_D')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mydata.plot()

# %%
mydata = quandl.get('EIA/PET_RWTC_D', returns= 'numpy')

# %%
mydata
# Out:
# rec.array([(datetime.datetime(1986, 1, 2, 0, 0),  25.56),
#            (datetime.datetime(1986, 1, 3, 0, 0),  26.  ),
#            (datetime.datetime(1986, 1, 6, 0, 0),  26.53), ...,
#            (datetime.datetime(2017, 9, 7, 0, 0),  49.1 ),
#            (datetime.datetime(2017, 9, 8, 0, 0),  47.44),
#            (datetime.datetime(2017, 9, 11, 0, 0),  48.06)],
#           dtype=[('Date', 'O'), ('Value', '<f8')])

# %%
# to access other data use the change the code 'ZILLOW/M11_NFS'
real_estate = quandl.get('ZILLOW/M11_NFS')

# %%
real_estate.plot()

# %%
# to get stock data just change the mydata name and the stock identifier 
mydata_stock = quandl.get('WIKI/AAPL')

# %%
mydata_stock.head()
# Out:
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  2093900.0          0.0          1.0
# 1980-12-15  27.38  27.38  27.25  27.25   785200.0          0.0          1.0
# 1980-12-16  25.37  25.37  25.25  25.25   472000.0          0.0          1.0
# 1980-12-17  25.87  26.00  25.87  25.87   385900.0          0.0          1.0
# 1980-12-18  26.63  26.75  26.63  26.63   327900.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 1980-12-12   0.422706   0.424470  0.422706    0.422706  117258400.0
# 1980-12-15   0.402563   0.402563  0.400652    0.400652   43971200.0
# 1980-12-16   0.373010   0.373010  0.371246    0.371246   26432000.0
# 1980-12-17   0.380362   0.382273  0.380362    0.380362   21610400.0
# 1980-12-18   0.391536   0.393300  0.391536    0.391536   18362400.0

# %%
#to get just one collum 
mydata_stock = quandl.get('WIKI/AAPL.1')

# %%
mydata_stock.head()
# Out:
#              Open
# Date
# 1980-12-12  28.75
# 1980-12-15  27.38
# 1980-12-16  25.37
# 1980-12-17  25.87
# 1980-12-18  26.63
